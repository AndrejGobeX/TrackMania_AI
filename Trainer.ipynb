# %% [markdown]
# # Trackmania_AI Colab Trainer

# %% [markdown]
# Run everything and download checkpoints.zip from the colab.
# Unzip it and replace the existing checkpoint in your directory with this one.

# %%
# !git clone https://github.com/AndrejGobeX/TrackMania_AI.git

# %%
import os
os.chdir('TrackMania_AI')

# %%
# !pwd
# Out:
# /content/TrackMania_AI

# %%
# !python Trainer.py (name of the model)

# %%
! zip -r checkpoints.zip Checkpoints/
